# %% [markdown]
# I have been using jupyter in some form since about 2016. I have used jupyterlab extensively, both natively, on binder, jupyterhub, and jupyterbooks.
# I am not up-to-date with developments since 2022. In particular the ai work in jupyter appears to be new.
#
# How broadly is usage of jupyter, colaboratory, solveit, kaggle and any similar systems?
#
# What should I look at to see how people are using the new ai for jupyter?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Great to connect with someone who's been in the Jupyter ecosystem for so long! Let me break this into the two parts you're asking about.
#
# ## Usage breadth
#
# The landscape has become quite fragmented. Jupyter remains the dominant open-source notebook interface, but usage has spread across several platforms:
#
# - **Jupyter/JupyterLab**: Still the standard for local development and research computing
# - **Google Colab**: Massive user base, especially in education and ML experimentation (free GPU access drives a lot of adoption)
# - **Kaggle**: Strong in the data science competition/learning community
# - **VS Code notebooks**: Growing significantly since Microsoft integrated notebook support
# - **Deepnote, Hex, Observable**: Various commercial alternatives targeting collaboration
# - **Solveit** (where you are now): Very new - just launched by fast.ai
#
# Hard usage numbers are difficult to compare across platforms, but Colab likely has the largest user base due to its accessibility, while JupyterLab remains the standard for serious research/development work.
#
# ## AI integration developments
#
# The main developments since 2022 are:
#
# 1. **jupyter-ai** - Official JupyterLab extension (launched 2023) that adds chat interface and magic commands for LLM interaction
# 2. **GitHub Copilot** integration in VS Code notebooks
# 3. **Colab's AI features** - they've added some AI-assisted coding features
# 4. **Various commercial notebook platforms** adding their own AI assistants
#
# To explore current usage patterns, I'd suggest:
#
# - The **jupyter-ai GitHub repo** (jupyter/jupyter-ai) - check issues and discussions to see real usage patterns
# - JupyterLab extension marketplace to see what AI extensions are popular
# - Recent JupyterCon talks (2023-2024) about AI integration
#
# What aspect interests you most - the technical integration approaches, or how people are actually using AI in their workflow?

# %% [markdown]
# I have been using solveit since November 3. On it now. I find the collaboration with ai agents to be wonderful.
# In January, I will be returning to using Jupyter because it is much easier to use, has great features across the
# spectrum for development.
# So I am really interested to see examples or articles about how jupyter-ai would be used by a developer. What should I most
# likely try to get the nice integration with development work using jupyterlab? For example, with the "lab" interface,
# one can easily work on python files, notebooks, csv files, markdown, all with a solid interface. With markdown, I
# can work on the source and see a view of it simultaneously.
# I am really looking for how-to, not theory, if possible.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Let me search for practical information about using jupyter-ai in development workflows.Perfect! I found some great practical resources. Let me search for one more thing - specific developer workflow examples.Great! I have good information now. Let me provide practical guidance focused on how-to aspects.
#
# Based on your experience with solveit and your upcoming return to JupyterLab, here's what you should focus on for practical jupyter-ai integration:
#
# ## Key things to try first
#
# **1. The two main interaction modes:**
#
# [*](https://github.com/jupyterlab/jupyter-ai "GitHub - jupyterlab/jupyter-ai: A generative AI extension for JupyterLab") [*](https://jupyter-ai.readthedocs.io/en/v2/ "Jupyter AI — Jupyter AI documentation") Jupyter AI offers an `%%ai` magic that turns the notebook into a reproducible generative AI playground, and [*](https://github.com/jupyterlab/jupyter-ai "GitHub - jupyterlab/jupyter-ai: A generative AI extension for JupyterLab") [*](https://jupyter-ai.readthedocs.io/en/v2/ "Jupyter AI — Jupyter AI documentation") a native chat UI in JupyterLab that enables you to work with generative AI as a conversational assistant.
#
# **2. Installation (JupyterLab 4):**
#
# [*](https://jupyter-ai.readthedocs.io/en/latest/users/index.html "Users — Jupyter AI documentation") Install conda and create an environment that uses Python 3.12 and the latest version of JupyterLab, then install with `pip install jupyter-ai[all]` to get all provider dependencies, or selectively install only what you need (e.g., just Anthropic or OpenAI).
#
# **3. Most useful for development workflow:**
#
# - **`%%ai` magic commands in cells** - [*](https://github.com/jupyterlab/jupyter-ai "GitHub - jupyterlab/jupyter-ai: A generative AI extension for JupyterLab") [*](https://github.com/jupyterlab/jupyter-ai "GitHub - jupyterlab/jupyter-ai: A generative AI extension for JupyterLab") Jupyter AI can interpolate IPython expressions, allowing you to run prompts that include variable values. This is huge for development - you can reference your dataframes, variables, etc. directly in prompts.
#
# - **Chat interface with context** - [*](https://www.deeplearning.ai/short-courses/jupyter-ai-coding-in-notebooks/ "Jupyter AI: AI Coding in Notebooks - DeepLearning.AI") You can drag existing cells into the chat for debugging, attach files for context, and save chat histories to reuse later as additional context. This fits well with multi-file development.
#
# - **`/learn` and `/ask` commands** - [*](https://blog.jupyter.org/generative-ai-in-jupyter-3f7174824862 "Generative AI in Jupyter. Jupyter AI, a new open source project… | by Jason Weill | Jupyter Blog") [*](https://blog.jupyter.org/generative-ai-in-jupyter-3f7174824862 "Generative AI in Jupyter. Jupyter AI, a new open source project… | by Jason Weill | Jupyter Blog") You can use the /learn command to teach Jupyternaut about local files, then use /ask to ask questions about them using retrieval-augmented generation (RAG). Great for working with your own documentation or codebases.
#
# ## Practical resources to check
#
# 1. **DeepLearning.AI course** - [*](https://www.deeplearning.ai/short-courses/jupyter-ai-coding-in-notebooks/ "Jupyter AI: AI Coding in Notebooks - DeepLearning.AI") [*](https://www.deeplearning.ai/short-courses/jupyter-ai-coding-in-notebooks/ "Jupyter AI: AI Coding in Notebooks - DeepLearning.AI") Build AI applications from scratch, including a book research assistant and a stock data analysis workflow, and learn how to provide API documentation as context. This launched November 2025 so it's current.
#
# 2. **GitHub examples directory** - [*](https://github.com/jupyterlab/jupyter-ai "GitHub - jupyterlab/jupyter-ai: A generative AI extension for JupyterLab") [*](https://github.com/jupyterlab/jupyter-ai "GitHub - jupyterlab/jupyter-ai: A generative AI extension for JupyterLab") The screenshots are from notebooks in the examples/ directory of the jupyter-ai package. Clone the repo and look at these.
#
# 3. **Local models tutorial** - [*](https://pandeyparul.medium.com/build-your-own-ai-coding-assistant-in-jupyterlab-with-ollama-and-hugging-face-1833684622f2 "Build Your Own AI Coding Assistant in JupyterLab with Ollama and Hugging Face | by Parul Pandey | Medium") A step-by-step guide to set up a local AI coding assistant in JupyterLab using Jupyter AI, Ollama and Hugging Face, capable of autocompleting code, fixing errors, creating new notebooks (from May 2025).
#
# ## What works best with JupyterLab's multi-file interface
#
# Since you mentioned working with Python files, notebooks, CSVs, and markdown simultaneously - the chat interface will be most valuable. You can keep it open in the sidebar while working across files, and the `/learn` command can index your project files so the AI understands your codebase context.
#
# Would you like specific examples of using the magic commands with variable interpolation, or help setting up the local model approach for privacy?

# %% [markdown]
# Let's start with examples. I am less concerned with privacy. Virtually anything I might do will be in a github public repo.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Great! Let me get you some concrete examples of the `%%ai` magic and variable interpolation in action.
#
# The most powerful feature for development is using `{variable}` syntax in your prompts. Here's a simple example:
#
# ```python
# import pandas as pd
# df = pd.read_csv('data.csv')
#
# # Now use the AI with your actual data
# %%ai chatgpt
# I have a dataframe called df with these columns: {df.columns.tolist()}
# and shape {df.shape}. Suggest 3 interesting analyses I could do.
# ```
#
# The AI sees your actual column names and data shape, making suggestions relevant to YOUR data.
#
# Another practical one for debugging:
#
# ```python
# result = some_complex_calculation()
#
# %%ai anthropic:claude-3-5-sonnet
# This result looks wrong: {result}
# Expected something around 100 but got this.
# Here's my function: {some_complex_calculation.__code__}
# What might be the issue?
# ```
#
# Have you installed jupyter-ai yet, or would you like me to show you more examples first to see if this workflow fits what you're looking for?

# %% [markdown]
# I installed it on a tljh instance on a cloud server. Once I get an NVMe drive on my RPi 5, I will also be playing with it locally.
#
# I have not yet figured out how to use it. I think I got some sort of exceptions just
# trying `%%ai`. That said, I don't think I really know how to configure it for some specific ai model. I don't think that `haiku`
# was even an option when I tried to set it up.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Ah, the configuration step is key! You need to set up your API keys and select a model provider first.
#
# Here's the quickest path:
#
# 1. **Open the chat interface** - Look for the chat icon in the left sidebar of JupyterLab (it should appear after installing jupyter-ai)
#
# 2. **Configure your provider** - In the chat UI, there's a settings/configuration area where you:
#    - Select your provider (e.g., "anthropic" for Claude models)
#    - Enter your API key
#    - Choose your specific model
#
# 3. **Then use the magic** - After configuration, the `%%ai` magic syntax is:
# ```python
# %%ai anthropic:claude-3-5-haiku
# Your prompt here
# ```
#
# The format is `%%ai provider:model-name`.
#
# Have you been able to open the chat interface in JupyterLab? That's where the configuration happens. If you're getting exceptions, it's likely because no provider is configured yet.

# %% [markdown]
# Does each `%%ai ...` need to identify the provider and model`?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Yes, each `%%ai` cell needs the provider:model specification.
#
# However, you can set a default model in the chat interface settings, and then you can use shorter aliases. For example, if you set Claude as your default, you might be able to just use `%%ai` without specifying.
#
# But the explicit `%%ai provider:model` format is more reliable and makes your notebooks more reproducible - anyone reading them knows exactly which model was used.
#
# Have you been able to access the chat interface settings yet to configure a provider?

# %% [markdown]
# I did get it installed enough to get the chat icon, eventually. I think I had to do some sort of refresh step or (??) to
# get the chat icon to appear on the sidebar.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Good progress! Yes, sometimes you need to refresh the browser or restart JupyterLab after installing extensions for them to appear.
#
# Now that you have the chat icon - have you clicked on it to open the chat interface? That's where you'll find the model configuration settings (usually a gear icon or settings button within the chat panel).

# %% [markdown]
# hehe. I did not mention that it was 2 weeks ago when I did that. ok. I just logged into my server and opened a notebook,
# ```
# %%ai anthropic:claude-3-5-haiku
# First test of ai chat in jupyterlab
# ```
# UsageError: Cell magic `%%ai` not found.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Ah! The extension is installed in JupyterLab, but the magic commands aren't available in your kernel yet.
#
# Try running this in a cell first:
#
# ```python
# %load_ext jupyter_ai
# ```
#
# Then try your `%%ai` cell again. Does that work?

# %% [markdown]
# from the %load_ext
# ```
# /home/jupyter-fred/.local/lib/python3.12/site-packages/google/cloud/aiplatform/models.py:52: FutureWarning: Support for google-cloud-storage < 3.0.0 will be removed in a future version of google-cloud-aiplatform. Please upgrade to google-cloud-storage >= 3.0.0.
#   from google.cloud.aiplatform.utils import gcs_utils
# ```
# From the cell above:
# ```
# In addition to the above, does it take a kernel restart to pick up the API that i just exported in Terminal?
#
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Yes, exactly! The kernel needs to see the environment variable. If you exported `ANTHROPIC_API_KEY` in your terminal, the kernel won't see it unless it was started after you set that variable.
#
# Two options:
#
# 1. **Restart the kernel** (Kernel menu → Restart Kernel)
# 2. **Or set it directly in the notebook:**
# ```python
# import os
# os.environ['ANTHROPIC_API_KEY'] = 'your-key-here'
# ```
#
# Try one of those, then run your `%%ai` cell again. Does it work now?

# %% [markdown]
# ```
# import os
# os.environ['ANTHROPIC_API_KEY'] = 'your-key-here'
# ```
# worked
# `export ANTHROPIC_API_KEY=...` did not. wrong shell?
#
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Great that it worked in the notebook!
#
# For the export - it depends on how your JupyterLab was started. If TLJH starts JupyterLab as a service, it won't see environment variables you set in your terminal session. You'd need to add it to the service configuration or to a shell profile that gets sourced when the service starts (like `~/.bashrc` or `~/.profile`), then restart the JupyterHub service.
#
# The in-notebook approach is simpler for now. You could put that `os.environ` line in a startup cell at the top of notebooks you want to use it in.
#
# Did your `%%ai` cell work after setting the key?

# %% [markdown]
# yes, nicely
#
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Excellent! Now you're set up and can start using it in your development workflow.
#
# Since you mentioned working with multiple file types in JupyterLab, you might want to try the `/learn` command in the chat interface next - it lets you index local files so the AI can answer questions about your codebase.
#
# What kind of development work are you planning to try jupyter-ai with first?

# %% [markdown]
# Should I prefer ~/.bashre or ~/.profile?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# For TLJH, use `~/.bashrc` - it's sourced for interactive shells and more reliably picked up by JupyterHub's spawning process.
#
# Add this line:
# ```bash
# export ANTHROPIC_API_KEY='your-key-here'
# ```
#
# Then you'll need to restart your JupyterHub server (log out and back in, or have an admin restart the service).
#
# But honestly, since you're experimenting, the in-notebook approach is fine for now. You can always move to proper configuration later.
#
# Did your `%%ai` test cell actually generate a response?

# %% [markdown]
# Thank you. Yes the magic generated a response. I also got a list of things to try from jupyternaut.
#
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Excellent! Now you're up and running.
#
# Since you mentioned wanting to see how this integrates with development work - what's a typical task you do in JupyterLab that you'd like to try with the AI integration? For example, working with data analysis, debugging code, or documenting something?

# %% [markdown]
# Actually, I probably should have asked the last question there.
#
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Perfect timing! So what would you like to try with jupyter-ai in your development workflow? What's a typical task you work on in JupyterLab?

# %% [markdown]
# it suggest the followin line magic:
# `%ai config model_id='anthropic-chat:claude-3-5-haiku-20241022'`
# then I got a traceback ending with
# `UsageError: No such command 'config'.`
#
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Hmm, that's odd. The `%ai config` command might not be available in your version, or the syntax has changed.
#
# Try checking what commands are available:
#
# ```python
# %ai help
# ```
#
# Or you can set the default model through the chat interface instead - click the gear/settings icon in the Jupyternaut chat panel. That's usually more reliable than the line magic.
#
# What does `%ai help` show you?

# %% [markdown]
# hehe. It shows a list of commands and model is not one of them. There is one called `register`
